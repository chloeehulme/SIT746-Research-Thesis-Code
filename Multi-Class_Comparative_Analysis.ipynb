# %% [markdown]
# # Mutli-Class Comparative Analysis

# %% [markdown]
# ## Data Pre-processing

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from tensorflow.keras import layers, models
from sklearn.metrics import confusion_matrix, precision_score, recall_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import RMSprop
from sklearn.model_selection import train_test_split

# %%
# Define dataframes for csvs
nonattack_csv = pd.read_csv('./multiclass_test/comp_analysis/non-attack_random_sample.csv')
dos_csv = pd.read_csv('./multiclass_test/comp_analysis/dos_output_OS.csv')
analysis_csv = pd.read_csv('./multiclass_test/comp_analysis/analysis_output_OS.csv')
backdoors_csv = pd.read_csv('./multiclass_test/comp_analysis/backdoors_output_OS.csv')
exploits_csv = pd.read_csv('./multiclass_test/comp_analysis/exploits_output_OS.csv')
generic_csv = pd.read_csv('./multiclass_test/comp_analysis/generic_output_OS.csv')
reconnaissance_csv = pd.read_csv('./multiclass_test/comp_analysis/recon_output_OS.csv')
shellcode_csv = pd.read_csv('./multiclass_test/comp_analysis/shellcode_output_OS.csv')
fuzzers_csv = pd.read_csv('./multiclass_test/comp_analysis/fuzzers_output_OS.csv')

# Create copies of dataframes
nonattack_copy = nonattack_csv.copy().head(16000)
dos_copy = dos_csv.copy()
analysis_copy = analysis_csv.copy()
backdoors_copy = backdoors_csv.copy()
exploits_copy = exploits_csv.copy()
generic_copy = generic_csv.copy()
reconnaissance_copy = reconnaissance_csv.copy()
shellcode_copy = shellcode_csv.copy()
fuzzers_copy = fuzzers_csv.copy()

# Correct labels of dataframes
analysis_copy['Label'] = 0
backdoors_copy['Label'] = 1
dos_copy['Label'] = 2
exploits_copy['Label'] = 3
fuzzers_copy['Label'] = 4
generic_copy['Label'] = 5
nonattack_copy['Label'] = 6
reconnaissance_copy['Label'] = 7
shellcode_copy['Label'] = 8

# %%
# Drop last two columns (attack category and data label)
nonattack_to_normal = nonattack_copy.drop(columns=['attack_cat', 'Label'])
dos_to_normal = dos_copy.drop(columns=['attack_cat', 'Label'])
analysis_to_normal = analysis_copy.drop(columns=['attack_cat', 'Label'])
backdoors_to_normal = backdoors_copy.drop(columns=['attack_cat', 'Label'])
exploits_output_OS = exploits_copy.drop(columns=['attack_cat', 'Label'])
generic_to_normal = generic_copy.drop(columns=['attack_cat', 'Label'])
reconnaissance_to_normal = reconnaissance_copy.drop(columns=['attack_cat', 'Label'])
shellcode_to_normal = shellcode_copy.drop(columns=['attack_cat', 'Label'])
fuzzers_to_normal = fuzzers_copy.drop(columns=['attack_cat', 'Label'])

# Normalise data
nonattack_normal = nonattack_to_normal / 255
dos_normal = dos_to_normal / 255
analysis_normal = analysis_to_normal / 255
backdoors_normal = backdoors_to_normal / 255
exploits_normal = exploits_output_OS / 255
generic_normal = generic_to_normal / 255
reconnaissance_normal = reconnaissance_to_normal / 255
shellcode_normal = shellcode_to_normal / 255
fuzzers_normal = fuzzers_to_normal / 255

# Add dropped columns back
nonattack_normal = pd.concat([nonattack_normal, nonattack_copy[['attack_cat', 'Label']]], axis=1)
dos_normal = pd.concat([dos_normal, dos_copy[['attack_cat', 'Label']]], axis=1)
analysis_normal = pd.concat([analysis_normal, analysis_copy[['attack_cat', 'Label']]], axis=1)
backdoors_normal = pd.concat([backdoors_normal, backdoors_copy[['attack_cat', 'Label']]], axis=1)
exploits_normal = pd.concat([exploits_normal, exploits_copy[['attack_cat', 'Label']]], axis=1)
generic_normal = pd.concat([generic_normal, generic_copy[['attack_cat', 'Label']]], axis=1)
reconnaissance_normal = pd.concat([reconnaissance_normal, reconnaissance_copy[['attack_cat', 'Label']]], axis=1).head(13940)
shellcode_normal = pd.concat([shellcode_normal, shellcode_copy[['attack_cat', 'Label']]], axis=1)
fuzzers_normal = pd.concat([fuzzers_normal, fuzzers_copy[['attack_cat', 'Label']]], axis=1)

nonattack_normal.head()
# Out:
#       srcip     sport     dstip    dsport     proto     state       dur  \
# 0  0.820513  0.476463  0.511628  0.732197  0.894737  0.076923  0.000017
# 1  0.974359  0.160601  0.558140  0.255702  0.849624  0.307692  0.025600
# 2  0.769231  0.027695  0.465116  0.018470  0.894737  0.076923  0.000075
# 3  0.820513  0.315975  0.581395  0.205011  0.850746  0.333333  0.000022
# 4  0.974359  0.457786  0.181818  0.008689  0.849624  0.357143  0.001126
#
#      sbytes    dbytes      sttl  ...  ct_ftp_cmd  ct_srv_src  ct_srv_dst  \
# 0  0.000010  0.000011  0.121569  ...         0.0    0.030303    0.075758
# 1  0.002870  0.000224  0.121569  ...         0.0    0.000000    0.045455
# 2  0.000044  0.000021  0.121569  ...         0.0    0.045455    0.045455
# 3  0.000123  0.000200  0.121569  ...         0.0    0.046512    0.146341
# 4  0.000022  0.000127  0.121569  ...         0.0    0.032258    0.032787
#
#    ct_dst_ltm  ct_src_ ltm  ct_src_dport_ltm  ct_dst_sport_ltm  \
# 0    0.030303     0.060606               0.0               0.0
# 1    0.045455     0.045455               0.0               0.0
# 2    0.015152     0.015152               0.0               0.0
# 3    0.000000     0.000000               0.0               0.0
# 4    0.016949     0.084746               0.0               0.0
#
#    ct_dst_src_ltm  attack_cat  Label
# 0        0.000000         NaN      6
# 1        0.015152         NaN      6
# 2        0.015152         NaN      6
# 3        0.000000         NaN      6
# 4        0.048387         NaN      6
#
# [5 rows x 49 columns]

# %%
# Train test split 70:30
nonattack_train_split = nonattack_normal.head(11200)
dos_train_split = dos_normal.head(11200)
analysis_train_split = analysis_normal.head(11200)
backdoors_train_split = backdoors_normal.head(11200)
exploits_train_split = exploits_normal.head(11200)
generic_train_split = generic_normal.head(11200)
reconnaissance_train_split = reconnaissance_normal.head(9760)
shellcode_train_split = shellcode_normal.head(11200)
fuzzers_train_split = fuzzers_normal.head(11200)

nonattack_test_split = nonattack_normal.tail(4800)
dos_test_split = dos_normal.tail(4800)
analysis_test_split = analysis_normal.tail(4800)
backdoors_test_split = backdoors_normal.tail(4800)
exploits_test_split = exploits_normal.tail(4800)
generic_test_split = generic_normal.tail(4800)
reconnaissance_test_split = reconnaissance_normal.tail(4180)
shellcode_test_split = shellcode_normal.tail(4800)
fuzzers_test_split = fuzzers_normal.tail(4800)

# %%
# Train set - validatin split 80:20, create X and y sets
X_train = pd.concat([nonattack_train_split.head(8960), dos_train_split.head(8960)], axis=0)
X_train = pd.concat([X_train, analysis_train_split.head(8960)], axis=0)
X_train = pd.concat([X_train, backdoors_train_split.head(8960)], axis=0)
X_train = pd.concat([X_train, exploits_train_split.head(8960)], axis=0)
X_train = pd.concat([X_train, generic_train_split.head(8960)], axis=0)
X_train = pd.concat([X_train, reconnaissance_train_split.head(7820)], axis=0)
X_train = pd.concat([X_train, shellcode_train_split.head(8960)], axis=0)
X_train = pd.concat([X_train, fuzzers_train_split.head(8960)], axis=0)

y_train = X_train[['Label']]
X_train = X_train.drop(columns=['attack_cat', 'Label'])

# %%
# Validation set - validation split 80:20, create X and y sets
X_val = pd.concat([nonattack_train_split.tail(2240), dos_train_split.tail(2240)], axis=0)
X_val = pd.concat([X_val, analysis_train_split.tail(2240)], axis=0)
X_val = pd.concat([X_val, backdoors_train_split.tail(2240)], axis=0)
X_val = pd.concat([X_val, exploits_train_split.tail(2240)], axis=0)
X_val = pd.concat([X_val, generic_train_split.tail(2240)], axis=0)
X_val = pd.concat([X_val, reconnaissance_train_split.tail(1940)], axis=0)
X_val = pd.concat([X_val, shellcode_train_split.tail(2240)], axis=0)
X_val = pd.concat([X_val, fuzzers_train_split.tail(2240)], axis=0)

y_val = X_val[['Label']]
X_val = X_val.drop(columns=['attack_cat', 'Label'])

# %%
# Reshape data to 20 row vectors for fair comparison, one-hot encode y labels
def reshape_data(X, y):
    # Reshape X
    X_array = X.to_numpy()
    samples, features = X.shape
    X_reshaped = X_array.reshape(-1, 20, features)

    # Reshape y
    y_array = y.to_numpy().flatten()
    y_reshaped = y_array[::20]

    # One-hot encode y
    y_one_hot = tf.keras.utils.to_categorical(y_reshaped, num_classes=9)

    return X_reshaped, y_one_hot

# Reshape and encode training data
X_train_reshaped, y_train_encoded = reshape_data(X_train, y_train['Label'])

# Reshape and encode validation data
X_val_reshaped, y_val_encoded = reshape_data(X_val, y_val['Label'])

# %%
# Test set
X_test = pd.concat([nonattack_test_split, dos_test_split], axis=0)
X_test = pd.concat([X_test, analysis_test_split], axis=0)
X_test = pd.concat([X_test, backdoors_test_split], axis=0)
X_test = pd.concat([X_test, exploits_test_split], axis=0)
X_test = pd.concat([X_test, generic_test_split], axis=0)
X_test = pd.concat([X_test, reconnaissance_test_split], axis=0)
X_test = pd.concat([X_test, shellcode_test_split], axis=0)
X_test = pd.concat([X_test, fuzzers_test_split], axis=0)

y_test = X_test[['Label']]
X_test = X_test.drop(columns=['attack_cat', 'Label'])

# Reshape and encode test data
X_test_reshaped, y_test_encoded = reshape_data(X_test, y_test['Label'])

# %%
# Early stopping
early_stopping = callbacks.EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

# %% [markdown]
# ## Artificial Neural Network (ANN)

# %%
# Model Architecture (from Sydney et al.)
model = Sequential([
    layers.Flatten(input_shape=(20, 47)),
    Dense(150, activation='relu'),
    Dense(9, activation='softmax')
])

# Create and compile the best performing model (with 150 neurons)
optimizer = Adam(learning_rate=0.02)
# Out:
# c:\Users\Admin\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Save results to CSV
csv_filename = './multiclass_test/comp_analysis/comp_ann_results.csv'


# Define the column names
fieldnames = ['trial_num', 'precision', 'recall', 'Analysis', 'Backdoors', 'DoS', 
              'Exploits', 'Fuzzers', 'Generic', 'Non-attack', 'Reconnaissance', 'Shellcode']

column_map = {
                0: 'Analysis',
                1: 'Backdoors',
                2: 'DoS',
                3: 'Exploits',
                4: 'Fuzzers',
                5: 'Generic',
                6: 'Non-attack',
                7: 'Reconnaissance',
                8: 'Shellcode'
            }


with open(csv_filename, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    
    for n in range(30):
        # Compile the model
        model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

        # Train the model
        ANN_history = model.fit(X_train_reshaped, 
                                y_train_encoded, 
                                epochs=50, 
                                batch_size=32, 
                                validation_data=(X_val_reshaped, y_val_encoded), 
                                callbacks=[early_stopping])
        
        # Make Predictions
        ANN_predictions = model.predict(X_test_reshaped)
        ANN_binary_predictions = np.where(ANN_predictions > 0.5, 1, 0)
        integer_predictions = np.argmax(ANN_binary_predictions, axis=1)

        # Flatten y_test
        true_labels = np.argmax(y_test_encoded, axis=1).squeeze()
        
        # Overall precision and recall
        precision = precision_score(true_labels, integer_predictions, average='macro')
        recall = recall_score(true_labels, integer_predictions, average='macro')
        
        # Calculate confusion matrix
        conf_matrix = confusion_matrix(true_labels, integer_predictions)

        # Prepare the row data
        row_data = {
            'trial_num': n,
            'precision': precision,
            'recall': recall
        }

        # Metrics for each class
        for i in range(conf_matrix.shape[0]):
            TP = conf_matrix[i, i]
            FP = conf_matrix[:, i].sum() - TP
            FN = conf_matrix[i, :].sum() - TP
            TN = conf_matrix.sum() - (FP + FN + TP)
            FPR = FP / (FP + TN) if (FP + TN) != 0 else 0
        
            # Calculate precision and recall
            class_precision = TP / (TP + FP) if (TP + FP) != 0 else 0
            class_recall = TP / (TP + FN) if (TP + FN) != 0 else 0

            # Add class-specific metrics to the row data
            row_data[column_map[i]] = f'TP: {TP} - FP: {FP} - FN: {FN} - TN: {TN} - FPR: {FPR:.4f} - Pr: {class_precision:.4f} - Re: {class_recall:.4f}'


        # Write the row to the CSV file
        writer.writerow(row_data)
        
        print(f"Trial {n} saved to {csv_filename}")
# Out:
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4957 - loss: 1.9407 - val_accuracy: 0.8308 - val_loss: 0.5956
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7934 - loss: 0.5973 - val_accuracy: 0.8590 - val_loss: 0.5331
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8216 - loss: 0.4887 - val_accuracy: 0.8278 - val_loss: 0.6200
# Epoch 4/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8530 - loss: 0.4108 - val_accuracy: 0.8671 - val_loss: 0.5000
# Epoch 5/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8364 - loss: 0.4748 - val_accuracy: 0.8973 - val_loss: 0.4504
# Epoch 6/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8470 - loss: 0.3845 - val_accuracy: 0.8892 - val_loss: 0.5335
# Epoch 7/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8699 - loss: 0.3459 - val_accuracy: 0.8610 - val_loss: 0.6347
# Epoch 8/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8643 - loss: 0.3842 - val_accuracy: 0.8207 - val_loss: 0.5545
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Trial 0 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8591 - loss: 0.3895 - val_accuracy: 0.8550 - val_loss: 0.5293
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8640 - loss: 0.3913 - val_accuracy: 0.8369 - val_loss: 0.4325
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8887 - loss: 0.2933 - val_accuracy: 0.8016 - val_loss: 0.7671
# Epoch 4/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8834 - loss: 0.3159 - val_accuracy: 0.8066 - val_loss: 0.6948
# Epoch 5/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8715 - loss: 0.3728 - val_accuracy: 0.8288 - val_loss: 0.6752
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step
# Trial 1 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8832 - loss: 0.3081 - val_accuracy: 0.7311 - val_loss: 1.0094
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8651 - loss: 0.3721 - val_accuracy: 0.8077 - val_loss: 0.5889
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8652 - loss: 0.3434 - val_accuracy: 0.8197 - val_loss: 0.7482
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Trial 2 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8691 - loss: 0.3795 - val_accuracy: 0.8157 - val_loss: 0.8439
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8791 - loss: 0.3518 - val_accuracy: 0.8167 - val_loss: 0.6990
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8840 - loss: 0.3323 - val_accuracy: 0.8459 - val_loss: 0.4826
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Trial 3 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8816 - loss: 0.3191 - val_accuracy: 0.7845 - val_loss: 0.8917
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8787 - loss: 0.3502 - val_accuracy: 0.7452 - val_loss: 1.0111
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8909 - loss: 0.3092 - val_accuracy: 0.8087 - val_loss: 0.7759
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step
# Trial 4 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8914 - loss: 0.3081 - val_accuracy: 0.7986 - val_loss: 0.7204
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8911 - loss: 0.3007 - val_accuracy: 0.8248 - val_loss: 0.6065
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8921 - loss: 0.2998 - val_accuracy: 0.8278 - val_loss: 0.6420
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Trial 5 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8789 - loss: 0.3367 - val_accuracy: 0.8197 - val_loss: 0.8277
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8927 - loss: 0.2919 - val_accuracy: 0.8691 - val_loss: 0.6064
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8678 - loss: 0.4220 - val_accuracy: 0.8781 - val_loss: 0.7866
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Trial 6 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8936 - loss: 0.2731 - val_accuracy: 0.8389 - val_loss: 0.7702
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8996 - loss: 0.2691 - val_accuracy: 0.8157 - val_loss: 0.7995
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8829 - loss: 0.3055 - val_accuracy: 0.8087 - val_loss: 0.8141
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step
# Trial 7 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8836 - loss: 0.2986 - val_accuracy: 0.8812 - val_loss: 0.5915
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8789 - loss: 0.3358 - val_accuracy: 0.8137 - val_loss: 0.7792
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8820 - loss: 0.3178 - val_accuracy: 0.8207 - val_loss: 0.6631
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step
# Trial 8 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9101 - loss: 0.2584 - val_accuracy: 0.7674 - val_loss: 0.9632
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8915 - loss: 0.2704 - val_accuracy: 0.7885 - val_loss: 1.0540
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9027 - loss: 0.2725 - val_accuracy: 0.8802 - val_loss: 0.6847
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step
# Trial 9 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8906 - loss: 0.2804 - val_accuracy: 0.8066 - val_loss: 0.8270
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8865 - loss: 0.3094 - val_accuracy: 0.8540 - val_loss: 0.6434
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8520 - loss: 0.3959 - val_accuracy: 0.8580 - val_loss: 0.6649
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step
# Trial 10 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8877 - loss: 0.2984 - val_accuracy: 0.8933 - val_loss: 0.5937
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9056 - loss: 0.2364 - val_accuracy: 0.8439 - val_loss: 0.6248
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9109 - loss: 0.2528 - val_accuracy: 0.7865 - val_loss: 0.9428
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# Trial 11 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9051 - loss: 0.2742 - val_accuracy: 0.8258 - val_loss: 0.9006
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8563 - loss: 0.4050 - val_accuracy: 0.7684 - val_loss: 1.0660
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8767 - loss: 0.3166 - val_accuracy: 0.8026 - val_loss: 0.8566
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step
# Trial 12 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8580 - loss: 0.4212 - val_accuracy: 0.8167 - val_loss: 0.7639
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8825 - loss: 0.3139 - val_accuracy: 0.8761 - val_loss: 0.6968
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8854 - loss: 0.3107 - val_accuracy: 0.8499 - val_loss: 0.6955
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step
# Trial 13 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8625 - loss: 0.3577 - val_accuracy: 0.8640 - val_loss: 0.9183
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8876 - loss: 0.3098 - val_accuracy: 0.8046 - val_loss: 0.7224
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8885 - loss: 0.2862 - val_accuracy: 0.8117 - val_loss: 0.9119
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step
# Trial 14 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8927 - loss: 0.2688 - val_accuracy: 0.7976 - val_loss: 1.0458
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9131 - loss: 0.2252 - val_accuracy: 0.8832 - val_loss: 0.7076
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8859 - loss: 0.2784 - val_accuracy: 0.8228 - val_loss: 0.7673
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step
# Trial 15 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8963 - loss: 0.2863 - val_accuracy: 0.8268 - val_loss: 0.7222
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8660 - loss: 0.3433 - val_accuracy: 0.8792 - val_loss: 0.7744
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9033 - loss: 0.2734 - val_accuracy: 0.7805 - val_loss: 1.1642
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step
# Trial 16 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9099 - loss: 0.2358 - val_accuracy: 0.8318 - val_loss: 0.7144
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8928 - loss: 0.2749 - val_accuracy: 0.7905 - val_loss: 1.0469
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8900 - loss: 0.3065 - val_accuracy: 0.8218 - val_loss: 0.7818
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step
# Trial 17 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9170 - loss: 0.2168 - val_accuracy: 0.8016 - val_loss: 0.8654
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9211 - loss: 0.2212 - val_accuracy: 0.8348 - val_loss: 0.9699
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9017 - loss: 0.2663 - val_accuracy: 0.8328 - val_loss: 0.7849
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step
# Trial 18 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9074 - loss: 0.2547 - val_accuracy: 0.8207 - val_loss: 0.7384
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8982 - loss: 0.2725 - val_accuracy: 0.8147 - val_loss: 1.5624
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8777 - loss: 0.3524 - val_accuracy: 0.8016 - val_loss: 0.9911
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step
# Trial 19 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9145 - loss: 0.2359 - val_accuracy: 0.8197 - val_loss: 0.9549
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9012 - loss: 0.2521 - val_accuracy: 0.8258 - val_loss: 0.8624
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8736 - loss: 0.3835 - val_accuracy: 0.7976 - val_loss: 1.1084
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step
# Trial 20 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8865 - loss: 0.3276 - val_accuracy: 0.7734 - val_loss: 1.0180
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8889 - loss: 0.2925 - val_accuracy: 0.8167 - val_loss: 1.1396
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8918 - loss: 0.2793 - val_accuracy: 0.7784 - val_loss: 1.3156
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step
# Trial 21 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9041 - loss: 0.2760 - val_accuracy: 0.8046 - val_loss: 1.0129
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9074 - loss: 0.2669 - val_accuracy: 0.8066 - val_loss: 0.7870
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8906 - loss: 0.2721 - val_accuracy: 0.8127 - val_loss: 1.0368
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step
# Trial 22 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9069 - loss: 0.2442 - val_accuracy: 0.8087 - val_loss: 0.9260
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8883 - loss: 0.3164 - val_accuracy: 0.7976 - val_loss: 0.9134
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9048 - loss: 0.2565 - val_accuracy: 0.8258 - val_loss: 0.9333
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step
# Trial 23 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9029 - loss: 0.2645 - val_accuracy: 0.8117 - val_loss: 1.0471
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9052 - loss: 0.2496 - val_accuracy: 0.7996 - val_loss: 1.0944
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9000 - loss: 0.2486 - val_accuracy: 0.8077 - val_loss: 1.2718
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step
# Trial 24 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8906 - loss: 0.3017 - val_accuracy: 0.8610 - val_loss: 0.8655
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8633 - loss: 0.3880 - val_accuracy: 0.7905 - val_loss: 1.1473
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9028 - loss: 0.2443 - val_accuracy: 0.8046 - val_loss: 1.0294
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step
# Trial 25 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9009 - loss: 0.2708 - val_accuracy: 0.8117 - val_loss: 0.7115
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9171 - loss: 0.2226 - val_accuracy: 0.8177 - val_loss: 0.9535
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8963 - loss: 0.2900 - val_accuracy: 0.8338 - val_loss: 0.8559
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step
# Trial 26 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9162 - loss: 0.2224 - val_accuracy: 0.7946 - val_loss: 1.1034
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8923 - loss: 0.2851 - val_accuracy: 0.8157 - val_loss: 0.7921
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8995 - loss: 0.2477 - val_accuracy: 0.8167 - val_loss: 1.0576
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Trial 27 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9097 - loss: 0.2233 - val_accuracy: 0.8127 - val_loss: 1.0322
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9169 - loss: 0.2222 - val_accuracy: 0.8127 - val_loss: 1.0739
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9077 - loss: 0.2411 - val_accuracy: 0.8107 - val_loss: 1.0717
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step
# Trial 28 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9289 - loss: 0.1992 - val_accuracy: 0.8127 - val_loss: 1.1051
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9091 - loss: 0.2369 - val_accuracy: 0.8177 - val_loss: 0.9517
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9007 - loss: 0.2417 - val_accuracy: 0.8379 - val_loss: 1.1023
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# Trial 29 saved to ./multiclass_test/comp_analysis/comp_ann_results.csv

# %%
## Long Short Term Memory

# %% [markdown]
# ## Long Short-Term Memory (LSTM)

# %%
# Model architecture (from Jallad et al.)
model = Sequential([
    LSTM(64, activation='relu', input_shape=(20, 47)),
    Dropout(0.5),
    Dense(9, activation='softmax')
])

# Compile
optimizer = RMSprop(learning_rate=0.001, rho=0.9, decay=0.0)
# Out:
# c:\Users\Admin\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# c:\Users\Admin\anaconda3\Lib\site-packages\keras\src\optimizers\base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(

# %%
# Save results to CSV
csv_filename = './multiclass_test/comp_analysis/comp_lstm_results.csv'


# Define the column names
fieldnames = ['trial_num', 'precision', 'recall', 'Analysis', 'Backdoors', 'DoS', 
              'Exploits', 'Fuzzers', 'Generic', 'Non-attack', 'Reconnaissance', 'Shellcode']

column_map = {
                0: 'Analysis',
                1: 'Backdoors',
                2: 'DoS',
                3: 'Exploits',
                4: 'Fuzzers',
                5: 'Generic',
                6: 'Non-attack',
                7: 'Reconnaissance',
                8: 'Shellcode'
            }


with open(csv_filename, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    
    for n in range(30):
        # Compile the model
        model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

        # Train the model
        LSTM_history = model.fit(X_train_reshaped, 
                                y_train_encoded, 
                                epochs=50, 
                                batch_size=32, 
                                validation_data=(X_val_reshaped, y_val_encoded), 
                                callbacks=[early_stopping])
        
        # Make Predictions
        LSTM_predictions = model.predict(X_test_reshaped)
        LSTM_binary_predictions = np.where(LSTM_predictions > 0.5, 1, 0)
        integer_predictions = np.argmax(LSTM_binary_predictions, axis=1)

        # Flatten y_test
        true_labels = np.argmax(y_test_encoded, axis=1).squeeze()
        
        # Overall precision and recall
        precision = precision_score(true_labels, integer_predictions, average='macro')
        recall = recall_score(true_labels, integer_predictions, average='macro')
        
        # Calculate confusion matrix
        conf_matrix = confusion_matrix(true_labels, integer_predictions)

        # Prepare the row data
        row_data = {
            'trial_num': n,
            'precision': precision,
            'recall': recall
        }

        # Metrics for each class
        for i in range(conf_matrix.shape[0]):
            TP = conf_matrix[i, i]
            FP = conf_matrix[:, i].sum() - TP
            FN = conf_matrix[i, :].sum() - TP
            TN = conf_matrix.sum() - (FP + FN + TP)
            FPR = FP / (FP + TN) if (FP + TN) != 0 else 0
        
            # Calculate precision and recall
            class_precision = TP / (TP + FP) if (TP + FP) != 0 else 0
            class_recall = TP / (TP + FN) if (TP + FN) != 0 else 0

            # Add class-specific metrics to the row data
            row_data[column_map[i]] = f'TP: {TP} - FP: {FP} - FN: {FN} - TN: {TN} - FPR: {FPR:.4f} - Pr: {class_precision:.4f} - Re: {class_recall:.4f}'


        # Write the row to the CSV file
        writer.writerow(row_data)
        
        print(f"Trial {n} saved to {csv_filename}")
# Out:
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.2971 - loss: 1.8559 - val_accuracy: 0.4914 - val_loss: 1.3542
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5457 - loss: 1.1878 - val_accuracy: 0.6737 - val_loss: 0.9280
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6568 - loss: 0.9095 - val_accuracy: 0.7815 - val_loss: 0.6564
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Trial 0 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# c:\Users\Admin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5441 - loss: 1.1925 - val_accuracy: 0.6939 - val_loss: 1.0845
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6658 - loss: 0.8958 - val_accuracy: 0.6818 - val_loss: 1.3883
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7260 - loss: 0.8477 - val_accuracy: 0.6918 - val_loss: 1.2718
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 1 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# c:\Users\Admin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.6543 - loss: 0.9336 - val_accuracy: 0.6999 - val_loss: 1.6575
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7315 - loss: 0.8269 - val_accuracy: 0.8026 - val_loss: 0.6312
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7838 - loss: 0.6520 - val_accuracy: 0.8097 - val_loss: 0.5882
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 2 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7103 - loss: 0.8316 - val_accuracy: 0.7956 - val_loss: 0.6441
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7733 - loss: 0.6609 - val_accuracy: 0.7986 - val_loss: 0.6402
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7877 - loss: 0.6507 - val_accuracy: 0.8359 - val_loss: 0.8947
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 3 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7666 - loss: 0.6681 - val_accuracy: 0.8741 - val_loss: 0.6491
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7820 - loss: 0.6139 - val_accuracy: 0.7956 - val_loss: 0.8527
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8018 - loss: 0.5616 - val_accuracy: 0.8721 - val_loss: 0.9023
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 4 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7941 - loss: 0.6075 - val_accuracy: 0.8399 - val_loss: 0.7251
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7981 - loss: 0.5647 - val_accuracy: 0.8852 - val_loss: 0.7554
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8261 - loss: 0.4944 - val_accuracy: 0.8671 - val_loss: 1.5159
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 5 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8089 - loss: 0.5590 - val_accuracy: 0.8308 - val_loss: 1.9881
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8080 - loss: 0.5434 - val_accuracy: 0.8459 - val_loss: 1.5046
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8274 - loss: 0.5201 - val_accuracy: 0.8852 - val_loss: 1.1479
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 6 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8185 - loss: 0.5564 - val_accuracy: 0.8902 - val_loss: 1.3683
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8310 - loss: 0.5269 - val_accuracy: 0.8338 - val_loss: 1.7959
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8418 - loss: 0.4753 - val_accuracy: 0.8036 - val_loss: 6.5543
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Trial 7 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8139 - loss: 0.6392 - val_accuracy: 0.8268 - val_loss: 1.8235
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8338 - loss: 0.4786 - val_accuracy: 0.8510 - val_loss: 3.3229
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8471 - loss: 0.5232 - val_accuracy: 0.9053 - val_loss: 2.7850
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 8 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8435 - loss: 0.4678 - val_accuracy: 0.9003 - val_loss: 1.2554
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8396 - loss: 0.4992 - val_accuracy: 0.8872 - val_loss: 5.1795
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8508 - loss: 0.4446 - val_accuracy: 0.8640 - val_loss: 2.8389
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 9 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8438 - loss: 0.4779 - val_accuracy: 0.9033 - val_loss: 1.5301
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8415 - loss: 0.4513 - val_accuracy: 0.7795 - val_loss: 3.4587
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8491 - loss: 0.4641 - val_accuracy: 0.8197 - val_loss: 8.1534
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 10 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8520 - loss: 0.4287 - val_accuracy: 0.9074 - val_loss: 2.6832
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8527 - loss: 0.4334 - val_accuracy: 0.9094 - val_loss: 4.6677
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8511 - loss: 0.4648 - val_accuracy: 0.8892 - val_loss: 2.5745
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 11 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8657 - loss: 0.4248 - val_accuracy: 0.8812 - val_loss: 4.1142
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8513 - loss: 0.5066 - val_accuracy: 0.9204 - val_loss: 2.0567
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8639 - loss: 0.4579 - val_accuracy: 0.8610 - val_loss: 6.1678
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 12 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8515 - loss: 0.4484 - val_accuracy: 0.8721 - val_loss: 4.5856
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8423 - loss: 0.5564 - val_accuracy: 0.8640 - val_loss: 3.5136
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8562 - loss: 0.4520 - val_accuracy: 0.7523 - val_loss: 12.6845
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 13 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8639 - loss: 0.4264 - val_accuracy: 0.9124 - val_loss: 4.3861
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8677 - loss: 0.3985 - val_accuracy: 0.8922 - val_loss: 14.6870
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8602 - loss: 0.4429 - val_accuracy: 0.8540 - val_loss: 7.4523
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 14 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8688 - loss: 0.4137 - val_accuracy: 0.8973 - val_loss: 4.7346
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8691 - loss: 0.3927 - val_accuracy: 0.8459 - val_loss: 4.9742
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8655 - loss: 0.9446 - val_accuracy: 0.8389 - val_loss: 5.7671
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 15 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8654 - loss: 0.4253 - val_accuracy: 0.9225 - val_loss: 4.7754
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8761 - loss: 0.4313 - val_accuracy: 0.9154 - val_loss: 6.5052
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8771 - loss: 0.3984 - val_accuracy: 0.7593 - val_loss: 15.8673
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 16 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8744 - loss: 0.3751 - val_accuracy: 0.8771 - val_loss: 7.8867
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8714 - loss: 0.8031 - val_accuracy: 0.9074 - val_loss: 4.1416
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8689 - loss: 0.3836 - val_accuracy: 0.9134 - val_loss: 10.3149
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 17 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8631 - loss: 0.6248 - val_accuracy: 0.9074 - val_loss: 3.9236
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8732 - loss: 0.4053 - val_accuracy: 0.7865 - val_loss: 8.7697
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8664 - loss: 0.3994 - val_accuracy: 0.7593 - val_loss: 7.1971
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 18 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8706 - loss: 0.4106 - val_accuracy: 0.8691 - val_loss: 7.7586
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8678 - loss: 0.3633 - val_accuracy: 0.9164 - val_loss: 14.4773
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8761 - loss: 0.3765 - val_accuracy: 0.9094 - val_loss: 7.5842
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 19 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8685 - loss: 0.3882 - val_accuracy: 0.9235 - val_loss: 9.1698
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8763 - loss: 0.3704 - val_accuracy: 0.8499 - val_loss: 6.5929
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8765 - loss: 0.4010 - val_accuracy: 0.9275 - val_loss: 9.4472
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 20 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8769 - loss: 0.3868 - val_accuracy: 0.8751 - val_loss: 14.0660
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8740 - loss: 0.3745 - val_accuracy: 0.8993 - val_loss: 17.2074
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8641 - loss: 2.5265 - val_accuracy: 0.8429 - val_loss: 15.6345
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 21 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8978 - loss: 0.3209 - val_accuracy: 0.9225 - val_loss: 14.6527
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8768 - loss: 0.4200 - val_accuracy: 0.9124 - val_loss: 8.2252
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8838 - loss: 0.3684 - val_accuracy: 0.8620 - val_loss: 11.1506
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 22 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8793 - loss: 0.4094 - val_accuracy: 0.8862 - val_loss: 19.0895
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8822 - loss: 0.3904 - val_accuracy: 0.9084 - val_loss: 17.2413
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8756 - loss: 0.4183 - val_accuracy: 0.8459 - val_loss: 19.9464
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 23 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8829 - loss: 0.3826 - val_accuracy: 0.9043 - val_loss: 13.9830
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8763 - loss: 0.3820 - val_accuracy: 0.8721 - val_loss: 11.7697
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8940 - loss: 0.3209 - val_accuracy: 0.8439 - val_loss: 12.0973
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 24 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8679 - loss: 0.4197 - val_accuracy: 0.8399 - val_loss: 30.5582
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8855 - loss: 0.6082 - val_accuracy: 0.9124 - val_loss: 14.0394
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8785 - loss: 4.4412 - val_accuracy: 0.8892 - val_loss: 17.9623
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 25 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8835 - loss: 0.4570 - val_accuracy: 0.8953 - val_loss: 20.4236
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9012 - loss: 0.3084 - val_accuracy: 0.8197 - val_loss: 27.2836
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8854 - loss: 0.6531 - val_accuracy: 0.9124 - val_loss: 21.1679
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 26 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8909 - loss: 0.3679 - val_accuracy: 0.8671 - val_loss: 14.4481
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8768 - loss: 0.3990 - val_accuracy: 0.9053 - val_loss: 28.4894
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8983 - loss: 0.3551 - val_accuracy: 0.8439 - val_loss: 26.7949
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 27 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8866 - loss: 0.4902 - val_accuracy: 0.9194 - val_loss: 25.5053
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8833 - loss: 0.3502 - val_accuracy: 0.8681 - val_loss: 37.7339
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8802 - loss: 1.2906 - val_accuracy: 0.8026 - val_loss: 56.1827
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 28 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8978 - loss: 0.3183 - val_accuracy: 0.8429 - val_loss: 5.9975
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8905 - loss: 0.9080 - val_accuracy: 0.8540 - val_loss: 35.2429
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8890 - loss: 0.3563 - val_accuracy: 0.9124 - val_loss: 35.1164
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Trial 29 saved to ./multiclass_test/comp_analysis/comp_lstm_results.csv

# %%
## 1D CNN

# %% [markdown]
# ## 1D Convolutional Neural Network (CNN)

# %%
# Model architecture
model = models.Sequential()
model.add(layers.Conv1D(64, 1, activation='relu', input_shape=(20, 47)))
model.add(layers.MaxPooling1D(1))

model.add(layers.Conv1D(64, 1, activation='tanh'))
model.add(layers.MaxPooling1D(1))

model.add(layers.Conv1D(96, 1, activation='tanh'))
model.add(layers.MaxPooling1D(1))

model.add(layers.Dropout(0.3))

# Flatten Layer
model.add(layers.Flatten())

# Dense Layer
model.add(layers.Dense(96, activation='relu'))
model.add(layers.Dropout(0.3))

# Output Layer
model.add(layers.Dense(9, activation='softmax'))

# Choose optimizer and learning rate
learning_rate = 0.0011228308916583806
optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
# Out:
# c:\Users\Admin\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Save results to CSV
csv_filename = './multiclass_test/comp_analysis/comp_1DCNN_results.csv'


# Define the column names
fieldnames = ['trial_num', 'precision', 'recall', 'Analysis', 'Backdoors', 'DoS', 
              'Exploits', 'Fuzzers', 'Generic', 'Non-attack', 'Reconnaissance', 'Shellcode']

column_map = {
                0: 'Analysis',
                1: 'Backdoors',
                2: 'DoS',
                3: 'Exploits',
                4: 'Fuzzers',
                5: 'Generic',
                6: 'Non-attack',
                7: 'Reconnaissance',
                8: 'Shellcode'
            }


with open(csv_filename, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    
    for n in range(30):
        # Compile the model
        model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

        # Train the model
        CNN_history = model.fit(X_train_reshaped, 
                                y_train_encoded, 
                                epochs=50, 
                                batch_size=32, 
                                validation_data=(X_val_reshaped, y_val_encoded), 
                                callbacks=[early_stopping])

        
        # Make Predictions
        CNN_predictions = model.predict(X_test_reshaped)
        CNN_binary_predictions = np.where(CNN_predictions > 0.5, 1, 0)
        integer_predictions = np.argmax(CNN_binary_predictions, axis=1)

        # Flatten y_test
        true_labels = np.argmax(y_test_encoded, axis=1).squeeze()
        
        # Overall precision and recall
        precision = precision_score(true_labels, integer_predictions, average='macro')
        recall = recall_score(true_labels, integer_predictions, average='macro')
        
        # Calculate confusion matrix
        conf_matrix = confusion_matrix(true_labels, integer_predictions)

        # Prepare the row data
        row_data = {
            'trial_num': n,
            'precision': precision,
            'recall': recall
        }

        # Metrics for each class
        for i in range(conf_matrix.shape[0]):
            TP = conf_matrix[i, i]
            FP = conf_matrix[:, i].sum() - TP
            FN = conf_matrix[i, :].sum() - TP
            TN = conf_matrix.sum() - (FP + FN + TP)
            FPR = FP / (FP + TN) if (FP + TN) != 0 else 0
        
            # Calculate precision and recall
            class_precision = TP / (TP + FP) if (TP + FP) != 0 else 0
            class_recall = TP / (TP + FN) if (TP + FN) != 0 else 0

            # Add class-specific metrics to the row data
            row_data[column_map[i]] = f'TP: {TP} - FP: {FP} - FN: {FN} - TN: {TN} - FPR: {FPR:.4f} - Pr: {class_precision:.4f} - Re: {class_recall:.4f}'


        # Write the row to the CSV file
        writer.writerow(row_data)
        
        print(f"Trial {n} saved to {csv_filename}")
# Out:
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4784 - loss: 1.4649 - val_accuracy: 0.7311 - val_loss: 0.7050
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7602 - loss: 0.6610 - val_accuracy: 0.7523 - val_loss: 0.6217
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8164 - loss: 0.5140 - val_accuracy: 0.8036 - val_loss: 0.5520
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 0 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7730 - loss: 0.6484 - val_accuracy: 0.7976 - val_loss: 0.4913
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8043 - loss: 0.5114 - val_accuracy: 0.9225 - val_loss: 0.3733
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8309 - loss: 0.4385 - val_accuracy: 0.8671 - val_loss: 0.4767
# Epoch 4/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8596 - loss: 0.3859 - val_accuracy: 0.8842 - val_loss: 0.4678
# Epoch 5/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8801 - loss: 0.3188 - val_accuracy: 0.8348 - val_loss: 0.5357
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 1 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8358 - loss: 0.4358 - val_accuracy: 0.8026 - val_loss: 0.5239
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8575 - loss: 0.3798 - val_accuracy: 0.8298 - val_loss: 0.4663
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8630 - loss: 0.3909 - val_accuracy: 0.8318 - val_loss: 0.4625
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 2 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8478 - loss: 0.4117 - val_accuracy: 0.8258 - val_loss: 0.4423
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8757 - loss: 0.3449 - val_accuracy: 0.8651 - val_loss: 0.4483
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8760 - loss: 0.3370 - val_accuracy: 0.8228 - val_loss: 0.5902
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 3 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8751 - loss: 0.3424 - val_accuracy: 0.8157 - val_loss: 0.6537
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8857 - loss: 0.3151 - val_accuracy: 0.8469 - val_loss: 0.4675
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8868 - loss: 0.3243 - val_accuracy: 0.7915 - val_loss: 0.6959
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 4 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8843 - loss: 0.3258 - val_accuracy: 0.8510 - val_loss: 0.4539
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8980 - loss: 0.2898 - val_accuracy: 0.8207 - val_loss: 0.7600
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8994 - loss: 0.2763 - val_accuracy: 0.8298 - val_loss: 0.5684
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 5 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9056 - loss: 0.2572 - val_accuracy: 0.8459 - val_loss: 0.4932
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9008 - loss: 0.2690 - val_accuracy: 0.8278 - val_loss: 0.6285
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8967 - loss: 0.2661 - val_accuracy: 0.8338 - val_loss: 0.5255
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 6 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9046 - loss: 0.2695 - val_accuracy: 0.8238 - val_loss: 0.5429
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8924 - loss: 0.2898 - val_accuracy: 0.8207 - val_loss: 0.6137
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9029 - loss: 0.2637 - val_accuracy: 0.8328 - val_loss: 0.5070
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 7 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9018 - loss: 0.2735 - val_accuracy: 0.8318 - val_loss: 0.5890
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9013 - loss: 0.2570 - val_accuracy: 0.8348 - val_loss: 0.6024
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8988 - loss: 0.2548 - val_accuracy: 0.8127 - val_loss: 0.8093
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 8 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9016 - loss: 0.2548 - val_accuracy: 0.8399 - val_loss: 0.5388
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9050 - loss: 0.2554 - val_accuracy: 0.8218 - val_loss: 0.6982
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9076 - loss: 0.2521 - val_accuracy: 0.8328 - val_loss: 0.5597
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 9 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9128 - loss: 0.2411 - val_accuracy: 0.7855 - val_loss: 0.9373
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9104 - loss: 0.2652 - val_accuracy: 0.8449 - val_loss: 0.6366
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9187 - loss: 0.2352 - val_accuracy: 0.8701 - val_loss: 0.3988
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 10 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9066 - loss: 0.2507 - val_accuracy: 0.8167 - val_loss: 0.8400
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9178 - loss: 0.2213 - val_accuracy: 0.8308 - val_loss: 0.6285
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9139 - loss: 0.2268 - val_accuracy: 0.7885 - val_loss: 1.1709
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 11 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9155 - loss: 0.2421 - val_accuracy: 0.8369 - val_loss: 0.6402
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9242 - loss: 0.2165 - val_accuracy: 0.8318 - val_loss: 0.5882
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9213 - loss: 0.2036 - val_accuracy: 0.8298 - val_loss: 0.6055
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 12 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9148 - loss: 0.2328 - val_accuracy: 0.8177 - val_loss: 0.6999
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9099 - loss: 0.2376 - val_accuracy: 0.8177 - val_loss: 0.6013
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9188 - loss: 0.2248 - val_accuracy: 0.8610 - val_loss: 0.4504
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 13 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9194 - loss: 0.2237 - val_accuracy: 0.8258 - val_loss: 0.7120
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9190 - loss: 0.2141 - val_accuracy: 0.8530 - val_loss: 0.5549
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9199 - loss: 0.2176 - val_accuracy: 0.8590 - val_loss: 0.4492
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 14 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9209 - loss: 0.2031 - val_accuracy: 0.8278 - val_loss: 0.7259
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9229 - loss: 0.2190 - val_accuracy: 0.8419 - val_loss: 0.5778
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9219 - loss: 0.2052 - val_accuracy: 0.8147 - val_loss: 0.7721
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 15 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9228 - loss: 0.2119 - val_accuracy: 0.8258 - val_loss: 0.6693
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9139 - loss: 0.2319 - val_accuracy: 0.8328 - val_loss: 0.6159
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9293 - loss: 0.1935 - val_accuracy: 0.8399 - val_loss: 0.5334
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 16 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9279 - loss: 0.1931 - val_accuracy: 0.8479 - val_loss: 0.6058
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9300 - loss: 0.1931 - val_accuracy: 0.8429 - val_loss: 0.5628
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9104 - loss: 0.2358 - val_accuracy: 0.8479 - val_loss: 0.6888
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 17 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9281 - loss: 0.1876 - val_accuracy: 0.8318 - val_loss: 0.7011
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9303 - loss: 0.1819 - val_accuracy: 0.8197 - val_loss: 0.8091
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9328 - loss: 0.1832 - val_accuracy: 0.8379 - val_loss: 0.5826
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 18 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9286 - loss: 0.1908 - val_accuracy: 0.8328 - val_loss: 0.5967
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9256 - loss: 0.1987 - val_accuracy: 0.8077 - val_loss: 0.8700
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9336 - loss: 0.1814 - val_accuracy: 0.8026 - val_loss: 1.0492
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 19 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9235 - loss: 0.2131 - val_accuracy: 0.8489 - val_loss: 0.5656
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9311 - loss: 0.1779 - val_accuracy: 0.8359 - val_loss: 0.6692
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9449 - loss: 0.1538 - val_accuracy: 0.8550 - val_loss: 0.6536
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 20 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9300 - loss: 0.1907 - val_accuracy: 0.8167 - val_loss: 0.7931
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9368 - loss: 0.1791 - val_accuracy: 0.8479 - val_loss: 0.5922
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9350 - loss: 0.1719 - val_accuracy: 0.7835 - val_loss: 1.0316
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 21 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9256 - loss: 0.2137 - val_accuracy: 0.8187 - val_loss: 0.8028
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9284 - loss: 0.2018 - val_accuracy: 0.8600 - val_loss: 0.5521
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9307 - loss: 0.1863 - val_accuracy: 0.8318 - val_loss: 0.6358
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 22 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9388 - loss: 0.1664 - val_accuracy: 0.8399 - val_loss: 0.6332
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9349 - loss: 0.1744 - val_accuracy: 0.8520 - val_loss: 0.5825
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9383 - loss: 0.1615 - val_accuracy: 0.8268 - val_loss: 0.6723
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 23 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9335 - loss: 0.1959 - val_accuracy: 0.8439 - val_loss: 0.6939
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9239 - loss: 0.1910 - val_accuracy: 0.8499 - val_loss: 0.5583
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9451 - loss: 0.1587 - val_accuracy: 0.8288 - val_loss: 0.7375
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 24 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9495 - loss: 0.1552 - val_accuracy: 0.8026 - val_loss: 0.9395
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9179 - loss: 0.2070 - val_accuracy: 0.8359 - val_loss: 0.7312
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9428 - loss: 0.1581 - val_accuracy: 0.8359 - val_loss: 0.6051
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 25 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9313 - loss: 0.1951 - val_accuracy: 0.9074 - val_loss: 0.4565
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9342 - loss: 0.1776 - val_accuracy: 0.8389 - val_loss: 0.6721
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9493 - loss: 0.1483 - val_accuracy: 0.8298 - val_loss: 0.7918
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 26 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9397 - loss: 0.1687 - val_accuracy: 0.8107 - val_loss: 0.8050
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9412 - loss: 0.1555 - val_accuracy: 0.8318 - val_loss: 0.6609
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9505 - loss: 0.1346 - val_accuracy: 0.7976 - val_loss: 1.1240
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 27 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9314 - loss: 0.1722 - val_accuracy: 0.8278 - val_loss: 0.7452
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9459 - loss: 0.1423 - val_accuracy: 0.8530 - val_loss: 0.7002
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9408 - loss: 0.1679 - val_accuracy: 0.8298 - val_loss: 0.6796
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 28 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9415 - loss: 0.1500 - val_accuracy: 0.8389 - val_loss: 0.6687
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9373 - loss: 0.1589 - val_accuracy: 0.8147 - val_loss: 0.9557
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9359 - loss: 0.1785 - val_accuracy: 0.8258 - val_loss: 0.8835
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Trial 29 saved to ./multiclass_test/comp_analysis/comp_1DCNN_results.csv
